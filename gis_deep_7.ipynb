# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
faults = pd.read_csv('/content/drive/MyDrive/faults_mini.csv')

display(faults.head())
display(faults.info())
display(faults.describe())
# Out:
#    X_Minimum  Y_Minimum  Pixels_Areas  ...  Pastry  Z_Scratch  K_Scatch
# 0         42     270900           267  ...       1          0         0
# 1       1084     185575           108  ...       0          0         1
# 2       1109    1170194           130  ...       0          1         0
# 3        190     210936           132  ...       1          0         0
# 4        330     429227           264  ...       1          0         0
#
# [5 rows x 7 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   X_Minimum              10 non-null     int64
#  1   Y_Minimum              10 non-null     int64
#  2   Pixels_Areas           10 non-null     int64
#  3   Steel_Plate_Thickness  10 non-null     int64
#  4   Pastry                 10 non-null     int64
#  5   Z_Scratch              10 non-null     int64
#  6   K_Scatch               10 non-null     int64
# dtypes: int64(7)
# memory usage: 688.0 bytes
# None
#          X_Minimum     Y_Minimum  Pixels_Areas  ...     Pastry  Z_Scratch   K_Scatch
# count    10.000000  1.000000e+01     10.000000  ...  10.000000  10.000000  10.000000
# mean    336.800000  4.980733e+05   1102.300000  ...   0.400000   0.300000   0.300000
# std     419.946769  3.014717e+05   1591.202973  ...   0.516398   0.483046   0.483046
# min      42.000000  1.855750e+05    108.000000  ...   0.000000   0.000000   0.000000
# 25%      48.750000  2.948952e+05    133.750000  ...   0.000000   0.000000   0.000000
# 50%     132.000000  4.033820e+05    265.500000  ...   0.000000   0.000000   0.000000
# 75%     380.250000  5.998238e+05   1240.500000  ...   1.000000   0.750000   0.750000
# max    1109.000000  1.170194e+06   4048.000000  ...   1.000000   1.000000   1.000000
#
# [8 rows x 7 columns]

# %%
#practice
var_x_outlier = [100]
var_x = np.random.randint(0,7, size = 99)
var_x = np.hstack([var_x, var_x_outlier])

var_y = np.random.randint(0, 40, size = 100)

print(var_x)
print("=============================================================================")
print(var_y)
print("=============================================================================")

var_x_norm = (var_x - var_x.min()) / (var_x.max() - var_x.min())
var_y_norm = (var_y - var_y.min()) / (var_y.max() - var_y.min())

print(var_x_norm[-1:])
print("================")
print(var_y_norm[:5])
print("=============================================================================")

plt.figure(figsize=(15,3))

plt.subplot(1,5,1)
sns.scatterplot(var_x,var_y, color = 'red')
plt.title("No Min - Max Nomalization")
plt.grid()

plt.subplot(1,5,3)
sns.scatterplot(var_x_norm,var_y_norm, color = 'orange')
plt.title('Min - Max Nomalization')
plt.grid()

var_x = np.random.randint(0,7,  size = 100)
var_y = np.random.randint(0,40, size = 100)

var_x_norm = (var_x - var_x.min()) / (var_x.max() - var_x.min())
var_y_norm = (var_y - var_y.min()) / (var_y.max() - var_y.min())

plt.subplot(1,5,5)
sns.scatterplot(var_x_norm, var_y_norm, color = 'blue')
plt.title('No Outlier Min Max Normalization')
plt.grid()

plt.show()
# Out:
# [  6   0   6   6   0   3   5   5   5   4   4   0   4   3   2   6   1   3
#    1   3   1   6   5   0   0   1   4   2   3   4   4   3   1   1   2   2
#    6   0   6   6   3   0   3   4   1   0   3   3   4   2   1   2   0   0
#    1   0   6   5   4   6   4   0   5   1   3   3   4   3   3   6   5   3
#    0   0   0   2   0   6   4   3   5   3   4   6   6   1   5   3   4   2
#    0   6   1   2   6   6   0   4   2 100]
# =============================================================================
# [ 3 17 26 12 39  4  8  4  1 33 33  0  5 37 28  3 29 27  9 17 15 19 27 18
#  34 17  1 23 19 36 26 21 38 38 11  2  4 38 18 18 27 24  6  5  7 13 28 27
#  30 39  5 33 38  0  1 10 31 34  8 18 31  1 31 10 25 30 32 13  1  1 33 10
#  10  9 25 28 31 18 25 20 32 31 31 18 18 34 32 10 13 37 11 23 32 11 28  8
#   8 37  3 22]
# =============================================================================
# [1.]
# ================
# [0.07692308 0.43589744 0.66666667 0.30769231 1.        ]
# =============================================================================
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#faults min-max
faults_norm = (faults - faults.min()) / (faults.max() - faults.min())
print(faults_norm.head())
display(faults_norm.describe())

print("============================")

print(faults_norm[:5])

faults_shuffle = faults_norm.sample(frac = 1)

print("============================")
print(faults_shuffle[:5])
# Out:
#    X_Minimum  Y_Minimum  Pixels_Areas  ...  Pastry  Z_Scratch  K_Scatch
# 0   0.000000   0.086658      0.040355  ...     1.0        0.0       0.0
# 1   0.976570   0.000000      0.000000  ...     0.0        0.0       1.0
# 2   1.000000   1.000000      0.005584  ...     0.0        1.0       0.0
# 3   0.138707   0.025757      0.006091  ...     1.0        0.0       0.0
# 4   0.269916   0.247458      0.039594  ...     1.0        0.0       0.0
#
# [5 rows x 7 columns]
#        X_Minimum  Y_Minimum  Pixels_Areas  ...     Pastry  Z_Scratch   K_Scatch
# count  10.000000  10.000000     10.000000  ...  10.000000  10.000000  10.000000
# mean    0.276289   0.317380      0.252360  ...   0.400000   0.300000   0.300000
# std     0.393577   0.306181      0.403859  ...   0.516398   0.483046   0.483046
# min     0.000000   0.000000      0.000000  ...   0.000000   0.000000   0.000000
# 25%     0.006326   0.111028      0.006536  ...   0.000000   0.000000   0.000000
# 50%     0.084349   0.221209      0.039975  ...   0.000000   0.000000   0.000000
# 75%     0.317010   0.420720      0.287437  ...   1.000000   0.750000   0.750000
# max     1.000000   1.000000      1.000000  ...   1.000000   1.000000   1.000000
#
# [8 rows x 7 columns]
# ============================
#    X_Minimum  Y_Minimum  Pixels_Areas  ...  Pastry  Z_Scratch  K_Scatch
# 0   0.000000   0.086658      0.040355  ...     1.0        0.0       0.0
# 1   0.976570   0.000000      0.000000  ...     0.0        0.0       1.0
# 2   1.000000   1.000000      0.005584  ...     0.0        1.0       0.0
# 3   0.138707   0.025757      0.006091  ...     1.0        0.0       0.0
# 4   0.269916   0.247458      0.039594  ...     1.0        0.0       0.0
#
# [5 rows x 7 columns]
# ============================
#    X_Minimum  Y_Minimum  Pixels_Areas  ...  Pastry  Z_Scratch  K_Scatch
# 0   0.000000   0.086658      0.040355  ...     1.0        0.0       0.0
# 7   0.332709   0.425447      0.085279  ...     0.0        1.0       0.0
# 1   0.976570   0.000000      0.000000  ...     0.0        0.0       1.0
# 6   0.008435   0.406539      0.007868  ...     0.0        1.0       0.0
# 2   1.000000   1.000000      0.005584  ...     0.0        1.0       0.0
#
# [5 rows x 7 columns]

# %%
faults_np = faults_shuffle.to_numpy()
print(type(faults_np))

train_ratio = 0.8
input_cnt  = 4
output_cnt = 3

train_idx = int(len(faults_np) * train_ratio)
print("train_idx : ", train_idx)

train_X, train_Y = faults_np[:train_idx , : -output_cnt], faults_np[:train_idx, -output_cnt : ]
test_X, test_Y   = faults_np[train_idx: , : -output_cnt], faults_np[train_idx : , -output_cnt :]

print(train_X.shape)
print(train_Y.shape)
print("======================")
print(test_X.shape)
print(test_Y.shape)
# Out:
# <class 'numpy.ndarray'>
# train_idx :  8
# (8, 4)
# (8, 3)
# ======================
# (2, 4)
# (2, 3)

# %%
simple_layer_model = tf.keras.Sequential([
                                          tf.keras.layers.Dense(units = 3,
                                                                activation = 'softmax',
                                                                input_shape = (4,))
])

# %%
simple_layer_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 3)                 15
# =================================================================
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________

# %%
simple_layer_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                           loss = 'categorical_crossentropy')
history_1 = simple_layer_model.fit(train_X, train_Y,
                                   epochs = 25, batch_size = 2)
# Out:
# Epoch 1/25
# 4/4 [==============================] - 1s 3ms/step - loss: 1.1502
# Epoch 2/25
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1469
# Epoch 3/25
# 4/4 [==============================] - 0s 5ms/step - loss: 1.1437
# Epoch 4/25
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1414
# Epoch 5/25
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1383
# Epoch 6/25
# 4/4 [==============================] - 0s 4ms/step - loss: 1.1360
# Epoch 7/25
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1334
# Epoch 8/25
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1307
# Epoch 9/25
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1286
# Epoch 10/25
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1258
# Epoch 11/25
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1230
# Epoch 12/25
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1213
# Epoch 13/25
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1183
# Epoch 14/25
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1157
# Epoch 15/25
# 4/4 [==============================] - 0s 4ms/step - loss: 1.1128
# Epoch 16/25
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1110
# Epoch 17/25
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1083
# Epoch 18/25
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1061
# Epoch 19/25
# 4/4 [==============================] - 0s 4ms/step - loss: 1.1030
# Epoch 20/25
# 4/4 [==============================] - 0s 4ms/step - loss: 1.1012
# Epoch 21/25
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0983
# Epoch 22/25
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0962
# Epoch 23/25
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0933
# Epoch 24/25
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0918
# Epoch 25/25
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0885

# %%
simple_layer_model.evaluate(test_X, test_Y)
# Out:
# 1/1 [==============================] - 0s 124ms/step - loss: 1.2479
# 1.2479331493377686

# %%
plt.figure(figsize=(12,4))
plt.plot(history_1.history['loss'], 'b--o', label = 'loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()

plt.show()

# %%
pred_Y = simple_layer_model.predict(test_X)
print("pred_Y : \n", pred_Y)
# Out:
# pred_Y :
#  [[0.2970965  0.22044726 0.48245627]
#  [0.2774351  0.21303016 0.5095347 ]]

# %%
pred_y = np.argmax(pred_Y, axis=1)
print(pred_y)
# Out:
# [2 2]

# %%
test_Y = np.argmax(test_Y, axis = 1)
print(test_Y)
# Out:
# [0 0]

# %%
acc = np.mean(np.equal(pred_y, test_Y))
print("ACC : {} %".format(acc))
# Out:
# ACC : 0.0 %
